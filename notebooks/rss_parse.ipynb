# %%
import feedparser
import json
import os

def verify_rss_json(json_file):
    # Read the JSON file
    with open(json_file, "r") as f:
        feeds = json.load(f)

    # Assert the JSON structure
    assert "name" in feeds, f"Missing 'name' in {json_file}"
    assert "rss_feeds" in feeds, f"Missing 'rss_feeds' in {json_file}"
    assert isinstance(feeds["rss_feeds"], list), f"'rss_feeds' should be a list in {json_file}"

    outlet_name = feeds["name"]

    for feed in feeds["rss_feeds"]:
        # Check for feed_name or name
        assert "feed_name" in feed or "name" in feed, f"Missing 'feed_name' or 'name' in one of the feeds in {json_file}"
        
        # Check for url or link
        assert "url" in feed or "link" in feed, f"Missing 'url' or 'link' in one of the feeds in {json_file}"

        feed_name = feed.get("feed_name", feed.get("name", "default_feed")).lower().replace(" ", "_")
        feed_url = feed.get("url", feed.get("link"))

        task_id = f'fetch_{outlet_name.lower().replace(" ", "_")}_{feed_name}'
        print(f"Task ID: {task_id}")

        # # Parse the feed URL to ensure it is valid
        # parsed_feed = feedparser.parse(feed_url)
        # assert parsed_feed.bozo == 0, f"Error parsing feed URL: {feed_url}"
        # print(f"Parsed feed URL successfully: {feed_url}")

# Path to the directory containing the JSON files
config_dir = os.path.join(os.getcwd(), "..", "airflow", "config", "news_outlets")

# Iterate over all JSON files in the config directory and verify them
for file_name in os.listdir(config_dir):
    if file_name.endswith(".json"):
        file_path = os.path.join(config_dir, file_name)
        print(f"Verifying JSON file: {file_path}")
        verify_rss_json(file_path)
# Out:
# Verifying JSON file: /home/luke/projects/clio/notebooks/../airflow/config/news_outlets/business_world.json
# Task ID: fetch_business_world_feed
# Verifying JSON file: /home/luke/projects/clio/notebooks/../airflow/config/news_outlets/gma.json
# Task ID: fetch_gma_public_affairs
# Task ID: fetch_gma_photo
# Task ID: fetch_gma_video
# Task ID: fetch_gma_newstv
# Task ID: fetch_gma_serbisyo_publiko
# Task ID: fetch_gma_walang_pasok
# Task ID: fetch_gma_transportation
# Task ID: fetch_gma_missing_persons
# Task ID: fetch_gma_news
# Task ID: fetch_gma_world
# Task ID: fetch_gma_metro
# Task ID: fetch_gma_nation
# Task ID: fetch_gma_regions
# Task ID: fetch_gma_special_reports
# Task ID: fetch_gma_ulat_filipino
# Task ID: fetch_gma_hashtag
# Task ID: fetch_gma_community_bulletin_board
# Task ID: fetch_gma_money
# Task ID: fetch_gma_personal_finance
# Task ID: fetch_gma_companies
# Task ID: fetch_gma_economy
# Task ID: fetch_gma_motoring
# Task ID: fetch_gma_sports
# Task ID: fetch_gma_basketball
# Task ID: fetch_gma_boxing
# Task ID: fetch_gma_football
# Task ID: fetch_gma_other_sports
# Task ID: fetch_gma_volleyball
# Task ID: fetch_gma_pinoy_abroad
# Task ID: fetch_gma_pinoy_achievers
# Task ID: fetch_gma_immigration_guide
# Task ID: fetch_gma_dispatch
# Task ID: fetch_gma_scitech
# Task ID: fetch_gma_science_and_research
# Task ID: fetch_gma_technology,_gadgets_and_gaming
# Task ID: fetch_gma_weather
# Task ID: fetch_gma_showbiz
# Task ID: fetch_gma_chika_minute
# Task ID: fetch_gma_showbiz_abroad
# Task ID: fetch_gma_pep
# Task ID: fetch_gma_lifestyle
# Task ID: fetch_gma_travel
# Task ID: fetch_gma_food
# Task ID: fetch_gma_art_and_culture
# Task ID: fetch_gma_health_and_wellness
# Task ID: fetch_gma_family_and_relationships
# Task ID: fetch_gma_shopping_and_fashion
# Task ID: fetch_gma_hobbies_and_activities
# Task ID: fetch_gma_opinion
# Task ID: fetch_gma_news_hardcore
# Verifying JSON file: /home/luke/projects/clio/notebooks/../airflow/config/news_outlets/philippine_star.json
# Task ID: fetch_philippine_star_headlines
# Task ID: fetch_philippine_star_opinion
# Task ID: fetch_philippine_star_nation
# Task ID: fetch_philippine_star_world
# Task ID: fetch_philippine_star_business
# Task ID: fetch_philippine_star_sports
# Task ID: fetch_philippine_star_entertainment
# Task ID: fetch_philippine_star_lifestyle
# Task ID: fetch_philippine_star_psn_bansa
# Task ID: fetch_philippine_star_psn_probinsiya
# Task ID: fetch_philippine_star_psn_metro
# Task ID: fetch_philippine_star_psn_opinyon
# Task ID: fetch_philippine_star_psn_palaro
# Task ID: fetch_philippine_star_psn_showbiz
# Task ID: fetch_philippine_star_the_freeman
# Task ID: fetch_philippine_star_pang-masa
# Task ID: fetch_philippine_star_banat
# Task ID: fetch_philippine_star_interaksyon_trends_+_spotlights
# Task ID: fetch_philippine_star_interaksyon_politics_+_issues
# Task ID: fetch_philippine_star_interaksyon_celebrities
# Task ID: fetch_philippine_star_interaksyon_hobbies_+_interests
# Task ID: fetch_philippine_star_interaksyon_rumor_cop
# Verifying JSON file: /home/luke/projects/clio/notebooks/../airflow/config/news_outlets/manila_times.json
# Task ID: fetch_manila_times_legal_advice
# Task ID: fetch_manila_times_news
# Task ID: fetch_manila_times_nation
# Task ID: fetch_manila_times_photos
# Task ID: fetch_manila_times_podcasts
# Task ID: fetch_manila_times_world
# Task ID: fetch_manila_times_regions
# Task ID: fetch_manila_times_the_sunday_times_magazine
# Task ID: fetch_manila_times_arts_awake
# Task ID: fetch_manila_times_filipino_champions
# Task ID: fetch_manila_times_fun_times
# Task ID: fetch_manila_times_literary_life
# Task ID: fetch_manila_times_people
# Task ID: fetch_manila_times_cover_story
# Task ID: fetch_manila_times_business
# Task ID: fetch_manila_times_agribusiness
# Task ID: fetch_manila_times_boardroom_watch
# Task ID: fetch_manila_times_build_&_design
# Task ID: fetch_manila_times_corporate_news
# Task ID: fetch_manila_times_foreign_business
# Task ID: fetch_manila_times_green_industries
# Task ID: fetch_manila_times_maritime
# Task ID: fetch_manila_times_stock_watch
# Task ID: fetch_manila_times_sunday_business_&_it
# Task ID: fetch_manila_times_top_business
# Task ID: fetch_manila_times_entertainment_&_lifestyle
# Task ID: fetch_manila_times_entertainment
# Task ID: fetch_manila_times_lifestyle
# Task ID: fetch_manila_times_opinion
# Task ID: fetch_manila_times_editorial
# Task ID: fetch_manila_times_editorial_cartoon
# Task ID: fetch_manila_times_columns
# Task ID: fetch_manila_times_from_our_readers
# Task ID: fetch_manila_times_expats_&_diplomats
# Task ID: fetch_manila_times_videos
# Task ID: fetch_manila_times_public_square
# Task ID: fetch_manila_times_sports
# Task ID: fetch_manila_times_special_features
# Task ID: fetch_manila_times_campus_press
# Task ID: fetch_manila_times_fast_times
# Verifying JSON file: /home/luke/projects/clio/notebooks/../airflow/config/news_outlets/inquirer.json
# Task ID: fetch_inquirer_full_feed
